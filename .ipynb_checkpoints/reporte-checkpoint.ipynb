# %% [markdown]
# # Análisis de estudiantes de la UC
# ###### Alberto Benavides

# %% [markdown]
# Primero se leen los datos y se muestran algunos datos en general.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('datos.csv')
df
# Out:
#       Sexo  Edad                 Municipio Trabaja  \
# 0        M   -28  San Nicolás de los Garza      NO
# 1        M    10                    García      NO
# 2        M    -6              Montemorelos      NO
# 3        M     3                 Monterrey      NO
# 4        H     6                 Guadalupe      NO
# ...    ...   ...                       ...     ...
# 41610    H   119                       NaN      NO
# 41611    M    86                 Monterrey      NO
# 41612    H  2020          General Escobedo      SI
# 41613    M  2020          General Escobedo      NO
# 41614    M  2020              Montemorelos      NO
#
#                                        ProgramaEducativo
# 0                                Licenciatura En Derecho
# 1                             Maestria En Administración
# 2      Licenciatura en Administración con Acentuación...
# 3                                Licenciatura En Derecho
# 4      Licenciatura en Administración con Acentuación...
# ...                                                  ...
# 41610                                       Bachillerato
# 41611  Maestria En Educación con acentuación en Tecno...
# 41612                            Licenciatura En Derecho
# 41613  Licenciatura en Administración con Acentuación...
# 41614                            Licenciatura En Derecho
#
# [41615 rows x 5 columns]

# %% [markdown]
# Se analizan ahora las edades, porque a simple vista parece haber algunas fuera de rango. Un diagrama de cajas y bigotes da una buena idea de esto.

# %%
plt.boxplot(df.Edad)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2cc04cf7940>,
#   <matplotlib.lines.Line2D at 0x2cc04cf7cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2cc04d17370>,
#   <matplotlib.lines.Line2D at 0x2cc04d176a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2cc04cf7910>],
#  'medians': [<matplotlib.lines.Line2D at 0x2cc04d179d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2cc04cf78b0>],
#  'means': []}

# %% [markdown]
# Hay edades muy grandes. De 2020, que posiblemente haya sido mala captura o confusión en la captura. Se eliminarán edades de más de 200 años.

# %%
df_copia = df[df.Edad < 200]
plt.boxplot(df_copia.Edad)
plt.show()

# %% [markdown]
# Ahora se ven algunas negativas, que dan la idea también de errores en captura. Se eliminan registros con edades negativas.

# %%
df_copia = df_copia[df_copia.Edad > 0]
plt.boxplot(df_copia.Edad)
plt.show()

# %% [markdown]
# Se eliminan ahora todos los registros con campos vacíos.

# %%
len(df_copia)
# Out:
# 41608

# %%
df_na = df_copia.dropna()
len(df_na)
# Out:
# 41422

# %% [markdown]
# Ahora se procede a revisar el resto de las columnas.

# %%
df_na.Sexo.unique()
# Out:
# array(['M', 'H'], dtype=object)

# %%
list(df_na.sort_values('Municipio').Municipio.unique())
# Out:
# ['Abasolo',
#  'Agualeguas',
#  'Allende',
#  'Anáhuac',
#  'Apodaca',
#  'Aramberri',
#  'Arteaga',
#  'Atotonilco de Tula',
#  'Benito Juárez',
#  'Bustamante',
#  'Cadereyta Jiménez',
#  'Cedral',
#  'Centro',
#  'Cerralvo',
#  'Chihuahua',
#  'China',
#  'Ciudad Valles',
#  'Ciénega de Flores',
#  'Coatzacoalcos',
#  'Coyoacán',
#  'Doctor Arroyo',
#  'Doctor Coss',
#  'Doctor González',
#  'Durango',
#  'El Carmen',
#  'Fresnillo',
#  'Galeana',
#  'García',
#  'General Bravo',
#  'General Cepeda',
#  'General Escobedo',
#  'General Terán',
#  'General Treviño',
#  'General Zaragoza',
#  'General Zuazua',
#  'Guadalajara',
#  'Guadalupe',
#  'Gómez Palacio',
#  'Hidalgo',
#  'Higueras',
#  'Hualahuises',
#  'Iturbide',
#  'Iztapalapa',
#  'Juárez',
#  'Lampazos de Naranjo',
#  'Linares',
#  'Los Aldamas',
#  'Los Herreras',
#  'Los Ramones',
#  'Lázaro Cárdenas',
#  'Marín',
#  'Matamoros',
#  'Matehuala',
#  'Mazatlán',
#  'Melchor Ocampo',
#  'Mexicali',
#  'Miguel Alemán',
#  'Miguel Hidalgo',
#  'Mina',
#  'Minatitlán',
#  'Monclova',
#  'Montemorelos',
#  'Monterrey',
#  'Muna',
#  'OTROS ESTADOS',
#  'Parras',
#  'Parás',
#  'Pesquería',
#  'Querétaro',
#  'Ramos Arizpe',
#  'Rayones',
#  'Reynosa',
#  'Rioverde',
#  'SIN MUNICIPIO',
#  'Sabinas Hidalgo',
#  'Salinas Victoria',
#  'Saltillo',
#  'San Carlos',
#  'San Nicolás de los Garza',
#  'San Pedro Garza García',
#  'Santa Catarina',
#  'Santiago',
#  'Soledad de Graciano Sánchez',
#  'Tampico',
#  'Tasquillo',
#  'Tepetitlán',
#  'Tlapa de Comonfort',
#  'Tlaxcala',
#  'Torreón',
#  'Tula de Allende',
#  'Vallecillo',
#  'Veracruz',
#  'Victoria',
#  'Villa de Álvarez',
#  'Villagrán',
#  'Villaldama',
#  'Zacatecas',
#  'Álvaro Obregón']

# %%
df_na.Trabaja.unique()
# Out:
# array(['NO', 'SI'], dtype=object)

# %%
list(df_na.ProgramaEducativo.unique())
# Out:
# ['Maestria En Administración',
#  'Licenciatura En Derecho',
#  'Licenciatura en Administración con Acentuación en Gestión Turística',
#  'Bachillerato',
#  'Licenciatura en Administración con Acentuación en Empresas',
#  'Licenciatura en Administración con Acentuación en Mercadotecnia',
#  'Licenciatura en Informatica Administrativa',
#  'Licenciatura en Derecho con Acentuación en Economía',
#  'Maestría en Administración con Acentuación en Finanzas',
#  'Maestría en Administración con Acentuación en Planeación Estratégica',
#  'Maestría en Administración con Acentuación en Sustentabilidad y Recursos Renovables',
#  'Maestria En Administración y Finanzas',
#  'Maestria En Administración y Mercadotecnia',
#  'Maestria En Administración y Recursos Humanos',
#  'Maestría en Derecho Agrario',
#  'Maestria En Educación con acentuación en Tecnología Educativa']

# %% [markdown]
# Ahora se procede a obtener estadísticas descriptivas por programas educativos.

# %%
df_programa = df_copia.groupby('ProgramaEducativo')

for n, g in df_programa:
    plt.figure(figsize=(4, 6))
    plt.boxplot(g.Edad)
    plt.ylabel("Edad")
    plt.xticks([], [])
    plt.title(n)
    plt.grid(True)
    plt.show()
    
    municipios = g.groupby('Municipio')
    m = []
    c = []
    for n1, g1 in municipios:
        m.append(n1)
        c.append(len(g1))

    t = pd.DataFrame({'cantidad': c, 'nombre': m})
    t = t.sort_values('cantidad', ascending=False)

    plt.figure(figsize=(20, 4))
    plt.bar(x=t.nombre, height=t.cantidad)
    plt.xticks(rotation=90)
    plt.title(n)
    plt.show()
    
    sexo = [len(g[g.Sexo == "H"]), len(g[g.Sexo == "M"])]
    plt.bar(x=['Hombres', 'Mujeres'], height=sexo)
    plt.suptitle(n)
    plt.title('Sexo')
    plt.show()
    
    trabaja = [len(g[g.Trabaja == "SI"]), len(g[g.Trabaja == "NO"])]
    plt.bar(x=['Sí', 'No'], height=trabaja)
    plt.suptitle(n)
    plt.title('Trabaja')
    plt.show()
